# %%
#! /usr/bin/python3.5

# %%
import math

import tensorflow as tf

import csv
from tensorflow.python.client import timeline
import pandas as pd
import math
import sys
import os
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
#dir_path = os.path.dirname(os.path.realpath(__file__))

#path_data_source=dir_path+"/data/data_source/"
path_data_source="/home/fsg/Desktop/"

#path_data_base=dir_path+"/data/database/csv/"


path_data_base="/home/fsg/Desktop/csv/"


files_path_data_source="files/"

#files_path_data_source="demo/"

#sub_path_data_source="small/"

file_path=path_data_source+files_path_data_source

file_names = [os.path.join(file_path, f) 
                      for f in os.listdir(file_path) 
                      if f.endswith(".txt")]


path_tf="sub_tf/"
path_idf="sub_idf/"
path_tfidf="sub_tfidf/"
path_sim_permutation="semantics/permutation/"
path_sim="semantics/sim/"
path_topic_document="topic_document/"

file_path_tf=path_data_base+path_tf
file_path_idf=path_data_base+path_idf
file_path_tfidf=path_data_base+path_tfidf
file_path_sim_permutation=path_data_base+path_sim_permutation
file_path_sim=path_data_base+path_sim
file_path_topic_document=path_data_base+path_topic_document

file_names_tf = [os.path.join(file_path_tf, f) 
                      for f in os.listdir(file_path_tf) 
                      if f.endswith(".csv")]
file_names_idf = [os.path.join(file_path_idf, f) 
                      for f in os.listdir(file_path_idf) 
                      if f.endswith(".csv")]


file_names_tfidf = [os.path.join(file_path_tfidf, f) 
                      for f in os.listdir(file_path_tfidf) 
                      if f.endswith(".csv")]


file_names_permutation = [os.path.join(file_path_sim_permutation, f) 
                      for f in os.listdir(file_path_sim_permutation) 
                      if f.endswith(".csv")]


file_names_sim = [os.path.join(file_path_sim, f) 
                      for f in os.listdir(file_path_sim) 
                      if f.endswith(".csv")]

file_names_topic_document = [os.path.join(file_path_topic_document, f) 
                      for f in os.listdir(file_path_topic_document) 
                      if f.endswith(".csv")]

# %%
#gpuN="0"#sys.argv[1]
#all_gpus ="2"#sys.argv[2]
#os.environ['CUDA_VISIBLE_DEVICES'] = gpuN
#gpu_name='/gpu:'+gpuN

task_no="0"#sys.argv[1]
all_gpus ="2"#sys.argv[2]
cuda="0,1"#sys.argv[3]
os.environ['CUDA_VISIBLE_DEVICES'] = cuda

# %%
import subprocess, re, os, sys #https://github.com/yaroslavvb/stuff/blob/master/notebook_util.py
def run_command(cmd):
    """Run command, return output as string."""
    
    output = subprocess.Popen(cmd, stdout=subprocess.PIPE, shell=True).communicate()[0]
    return output.decode("ascii")

# %%
def list_available_gpus():
    """Returns list of available GPU ids."""
    
    output = run_command("nvidia-smi -L")
    # lines of the form GPU 0: TITAN X
    gpu_regex = re.compile(r"GPU (?P<gpu_id>\d+):")
    result = []
    for line in output.strip().split("\n"):
        m = gpu_regex.match(line)
        assert m, "Couldnt parse "+line
        result.append(int(m.group("gpu_id")))
    return result

# %%
def save_txt(txt,file):
    text_file = open(file, "w")
    text_file.write(txt)
    text_file.close()

# %%
def gpu_memory_map(gpu_memory_file,gpu_output_file):
    """Returns map of GPU id to memory allocated on that GPU."""

    output = run_command("nvidia-smi")
    save_txt(output,gpu_output_file)
    #print("nvidia-smi",output)
    gpu_output = output[output.find("GPU Memory"):]
    #print("GPU Memory",gpu_output)
    save_txt(gpu_output,gpu_memory_file)
   
    # lines of the form
    # |    0      8734    C   python                                       11705MiB |
    memory_regex = re.compile(r"[|]\s+?(?P<gpu_id>\d+)\D+?(?P<pid>\d+).+[ ](?P<gpu_memory>\d+)MiB")
    #print("memory_regex",memory_regex)
    rows = gpu_output.split("\n")
    #print("rows",rows)
    result = {gpu_id: 0 for gpu_id in list_available_gpus()}
    #print("result",result)
    for row in gpu_output.split("\n"):
        m = memory_regex.search(row)
        if not m:
            continue
        gpu_id = int(m.group("gpu_id"))
        gpu_memory = int(m.group("gpu_memory"))
        result[gpu_id] += gpu_memory
    return result

# %%
def read_cvs_by_pands(path_database,file_database,index_col, header):
    import csv
    import pandas as pd
    return pd.read_csv(path_database+file_database,index_col=index_col,header=header)

# %%
def read_cvs_by_pands_full_path(full_path,index_col, header):
    import csv
    import pandas as pd
    return pd.read_csv(full_path,index_col=index_col,header=header)

# %%
def save_df_to_csv(df,path_database,sub_path,new_file_name):
     df.to_csv(path_database+sub_path+new_file_name)

# %%
def df_to_dict(df):
        
    dic={}
    keys=df.keys()
    #print(keys)
    
    values= df.T.values.tolist()
    #print(len(values))
    for i in range(len(keys)):
        #print(keys[i])
        dic[keys[i]]=magic(values[i])
    return dic

# %%
def magic(numList):         # [1,2,3]
    s = map(str, numList)   # ['1','2','3']
    s = ''.join(s)          # '123'
    s = int(s)              # 123
    return s

# %%
def list_to_dict(list_full_path):
    dic={}
    for file_path in list_full_path:
        index=full_name_file(file_path)
        dic[index]=file_path

    return dic

# %%
from nltk.corpus import wordnet as wn
from nltk.corpus import wordnet_ic as wnic
from nltk.tokenize import word_tokenize

def similarity_by_infocontent(sense1, sense2, option):
    #sense1="Synset('"+sense1+"')"
    #sense2="Synset('"+sense2+"')"
    #print(sense1,sense2)
    sense1 = wn.synset(sense1)
    sense2 = wn.synset(sense2)
    #print(sense1,sense2)
    """ Returns similarity scores by information content. """
    #if sense1.pos != sense2.pos: # infocontent sim can't do diff POS.
        #return 0

    info_contents = ['ic-bnc-add1.dat', 'ic-bnc-resnik-add1.dat', 
                     'ic-bnc-resnik.dat', 'ic-bnc.dat', 

                     'ic-brown-add1.dat', 'ic-brown-resnik-add1.dat', 
                     'ic-brown-resnik.dat', 'ic-brown.dat', 

                     'ic-semcor-add1.dat', 'ic-semcor.dat',

                     'ic-semcorraw-add1.dat', 'ic-semcorraw-resnik-add1.dat', 
                     'ic-semcorraw-resnik.dat', 'ic-semcorraw.dat', 

                     'ic-shaks-add1.dat', 'ic-shaks-resnik.dat', 
                     'ic-shaks-resnink-add1.dat', 'ic-shaks.dat', 

                     'ic-treebank-add1.dat', 'ic-treebank-resnik-add1.dat', 
                     'ic-treebank-resnik.dat', 'ic-treebank.dat']

    if option in ['res', 'resnik']:
        #return wn.res_similarity(sense1, sense2, wnic.ic('ic-bnc-resnik-add1.dat'))
        #print('simRe snik (c1,c2) = -log p(lso(c1,c2)) = IC(lso(c1,c2)')
        return wn.res_similarity(sense1, sense2, wnic.ic('ic-treebank-resnik-add1.dat'))
    #return min(wn.res_similarity(sense1, sense2, wnic.ic(ic)) \
    #             for ic in info_contents)

    elif option in ['jcn', "jiang-conrath"]:
        #return wn.jcn_similarity(sense1, sense2, wnic.ic('ic-bnc-add1.dat'))
        #print('sim(jcn) (c1,c2 )= (IC(c1) + IC(c2 )) - 2IC(lso(c1,c2 ))')
        return wn.jcn_similarity(sense1, sense2, wnic.ic('ic-treebank.dat'))

    elif option in ['lin']:
        #return wn.lin_similarity(sense1, sense2, wnic.ic('ic-bnc-add1.dat'))
        #print('sim(lin) (c1,c2)=(2IC(lso(c1,c2 )))/(IC(c1)+IC(c2))')
        return wn.lin_similarity(sense1, sense2, wnic.ic('ic-treebank.dat'))

def sim(sense1, sense2, option="path"):
    """ Calculates similarity based on user's choice. """
    option = option.lower()
    if option.lower() in ["path", "path_similarity", 
                        "wup", "wupa", "wu-palmer", "wu-palmer",
                        'lch', "leacock-chordorow"]:
        return similarity_by_path(sense1, sense2, option) 
    elif option.lower() in ["res", "resnik",
                          "jcn","jiang-conrath",
                          "lin"]:
        return similarity_by_infocontent(sense1, sense2, option)

def max_similarity(context_sentence, ambiguous_word, option="path", 
                   pos=None, best=True):
    """
    Perform WSD by maximizing the sum of maximum similarity between possible 
    synsets of all words in the context sentence and the possible synsets of the 
    ambiguous words (see http://goo.gl/XMq2BI):
    {argmax}_{synset(a)}(\sum_{i}^{n}{{max}_{synset(i)}(sim(i,a))}
    """
    result = {}
    for i in wn.synsets(ambiguous_word):
        try:
            if pos and pos != str(i.pos()):
                continue
        except:
            if pos and pos != str(i.pos):
                continue
        result[i] = sum(max([sim(i,k,option) for k in wn.synsets(j)]+[0]) \
                        for j in word_tokenize(context_sentence))

    if option in ["res","resnik"]: # lower score = more similar
        result = sorted([(v,k) for k,v in result.items()])
    else: # higher score = more similar
        result = sorted([(v,k) for k,v in result.items()],reverse=True)
    #print (result)
    if best: return result[0][1];
    return result

# %%
def isfile_empty(file_path_name):
    f=open(file_path_name, 'r') 
    is_blank = len(f.read().strip()) == 0
    return is_blank

# %%
def full_name_file(full_name_path):#like cs.csv
    d=full_name_path.split("/")
    ##print(d)
    name=d[len(d)-1]#.split(".")
    return name

# %%
def read_last_file_list(file_path,extention):
    
    file_names = [os.path.join(file_path, f) 
                      for f in os.listdir(file_path) 
                      if f.endswith(extention) and not isfile_empty(file_path+f)]
    return file_names

# %%
#permutation
def permutation(path_data_base,path_sim,path_sim_permutation):
    # open file Sim 
    sim_list=read_last_file_list(path_data_base+path_sim,"csv")
    #print(len(sim_list))
    for y in range(len(sim_list)):

        file_name=full_name_file(str(sim_list[y]))
        #print(file_name)
        Topic_name=file_name[:-4]
        #print(Topic_name)
        topic_df=read_cvs_by_pands(path_data_base,path_sim+file_name,None
                          ,None)


        #print(len(topic_df))
        main_Topic=[]
        sub_topic=[]
        true_list=[]
        list_removed=[]
        for i in range (len(topic_df)):
            #print(i)
            #print(topic_df.iloc[i][0])
            if topic_df.iloc[i][0]==Topic_name:
                #exclud from list wordwith the same name file
                main_Topic=list(topic_df.iloc[i])
                true_list.append(main_Topic)
                #print(type(main_Topic))
                #print(main_Topic)
                sub_topic =topic_df[topic_df.index != i].values.tolist()
                break

                # list after remove main topic
        if len(sub_topic)>1:
            for term in range(len(sub_topic)):
                if term not in list_removed:

                    #print("-------------------------------------")
                    #print("============Term==========",sub_topic[term][0])

                    is_term_good=True
                    for next_term in sub_topic[term+1:]:

                        #print(next_term[0])
                        result=similarity_by_infocontent(sub_topic[term][0],next_term[0],'res')
                        if result<1:
                            if sub_topic[term][1]>next_term[1]:
                                list_removed.append(next_term[0])
                            else:
                                list_removed.append(sub_topic[term][0])

                            is_term_good=False
                            #print(sub_topic[term][0],next_term[0],result,"xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
                            break
                    if is_term_good:
                        true_list.append(sub_topic[term])
                else:
                    print("------------term removed-------------------------",term)
            #print(true_list)
            perm_df=pd.DataFrame(true_list)
            #print(" print new file to perm")
            save_df_to_csv(perm_df,path_data_base,path_sim_permutation,file_name)
        else:
            #print(" copy origenal file to perm")
            save_df_to_csv(topic_df,path_data_base,path_sim_permutation,file_name)


        #compare each item withothers 
        #each term with next term 
        #if relation is less than one 
        #remove term with origenal small value
        #and new list in next compare

# %%
def log_idf(D,d,base):
    return math.log((D/d), base)

# %%
def idf_df(df,D,base):
    #[7/df['0']]
    y = [log_idf(D,x,base) for x in df[0]]
    return y

# %%
def read_sord_tf_file(path_data_source,sub_path_data_source_tf,i):
    #df=read_cvs_by_pands(path_data_source,sub_path_data_source_tf+"cs"+str(i)+".csv",0,header=0)
    #print("nnnnnnnnnnnn",path_data_source+sub_path_data_source_tf+i)
    df=read_cvs_by_pands(path_data_source,sub_path_data_source_tf+i,0,header=0)
    #ee.T.sort_index(inplace=True)
    df = df.T.sort_index()
    return df

# %%
def read_sord_idf_file(path_data_source,sub_path_data_source_idf,i):
    #df=read_cvs_by_pands(path_data_source,sub_path_data_source_idf+"cs"+str(i)+".csv",0,header=0)
    df=read_cvs_by_pands(path_data_source,sub_path_data_source_idf+i,0,header=0)
    #ee.T.sort_index(inplace=True)
    df = df.T.sort_index()
    return df

# %%
#d1={'a': 1, 'b': 1, 'c': 1}
def dict_to_DF(dic):
    df=pd.DataFrame([dic])
    return df

#dict_to_DF(d1)

# %%
def save_df_to_csv(df,path_database,sub_path,new_file_name):
     df.to_csv(path_database+sub_path+new_file_name)

# %%
def tf_idf_one(path_data_source,sub_path_data_source_tf,sub_path_data_source_idf,i,sub_path_data_source_tfidf):
    df_tf=read_sord_tf_file(path_data_source,sub_path_data_source_tf,i)
    df_idf=read_sord_idf_file(path_data_source,sub_path_data_source_idf,i)

    if len(df_idf) != 0:
        idf=idf_df(df_idf,len(df_idf),10)

        full_tfidf=[]
        for index in range(len(idf)):
            #print(index)
            tfidf=df_tf[0][index]*idf[index]
            full_tfidf.append(tfidf)


    df_tf_idf=pd.DataFrame(full_tfidf)
    df_tf_idf.index=df_tf.index
    #df_tf_idf.to_csv(path_data_source+sub_path_data_source_tfidf+"cs"+str(i)+".csv")
    df_tf_idf.to_csv(path_data_source+sub_path_data_source_tfidf+i)

# %%
def tf_idfs(list_tf,list_idf):
    #print(list_tf,list_idf)
    for tf_file in list_tf:
        tf_file_name=full_name_file(tf_file)
        #print(tf_file_name)
        for idf_file in list_idf:
            idf_file_name=full_name_file(idf_file)
            if tf_file_name == idf_file_name:
                #print(idf_file_name)
                tf_idf_one(path_data_base,path_tf,path_idf,tf_file_name,path_tfidf)

# %%
def is_file_exist(file_path,file_name):
    file_names = [os.path.join(file_path, f) 
                      for f in os.listdir(file_path) 
                      if f.endswith(".csv")]
    #print(file_names)
    if file_name in file_names:
        #print("d")
        return True
    else:
        #print("dd")
        return False

# %%
#is_file_exist('/home/fsg/Desktop/csv/semantics/permutation/','/home/fsg/Desktop/csv/semantics/permutation/situation.n.03.csv')
# Out:
# d
# True

# %%
def isfile_empty(file_path_name):
    import pandas as pd
    df1=pd.read_csv(file_path_name)
    is_blank=len(df1)==0
    return is_blank

# %%
#isfile_empty('/home/fsg/Desktop/csv/semantics/permutation/1530s.n.01.csv') #situation.n.03.csv')
# Out:
# False

# %%
# Out:
# 0

# %%
#to calculate H
#load list V(TF-IDF)
#loop perfile
#hold term
#open  the same name in topic "permutation"
#scalar multiblication: multible each 
#value of this word in V file by all items (terms)
#in topic file then sum and put result  in new file for topic document 
#def W_topic_doc(file_names_tfidf,file_path_sim_permutation,path_topic_document,path_data_base):
def W_topic_doc(tfidf_file,path_topic_document,path_data_base):
    #premu_dic=list_to_dict(file_path_sim_permutation)
    #tfidf_dict=list_to_dict(file_names_tfidf)
    #print(tfidf_dict)
    
    #for tfidf_file in file_names_tfidf:
        
    file_name=full_name_file(tfidf_file)
    #print("File: ",file_name,"\n")
    tfidf_df=read_cvs_by_pands_full_path(tfidf_file,0,0)
    df_index=tfidf_df.index
    result_W={}
    for index in df_index:
        #print("Term will be Topic: ",index,"\n")
        if is_file_exist(file_path_sim_permutation,file_path_sim_permutation+index.replace("/", "_")+'.csv'):
        
            full_topic_path=file_path_sim_permutation+index.replace("/", "_")+'.csv'#premu_dic.get(index+'.csv')
            print(full_topic_path)
            if not isfile_empty(full_topic_path):

                topic_df=read_cvs_by_pands_full_path(full_topic_path,0,0)
                #print("fffffffffffffff",tfidf_df.loc[index][0])

                #print("Topic-Terms:\n",topic_df['0'],"\n")
                try:
                    sum_terms_topic=sum([tfidf_df.loc[index][0] * x for x in topic_df['1']])
                    result_W[index]=sum_terms_topic
                except:
                    result_W[index]=0
                    
            else:
                result_W[index]=0
            #print("Sum: ",sum_terms_topic,"\n")
        else:
             result_W[index]=0
    W_df=dict_to_DF(result_W)
    #print("Save",file_name)
    save_df_to_csv(W_df,path_data_base,path_topic_document,file_name)
    #print("All: ",result_W,"\n")
#return result_W

# %%
#file_names_tfidf=read_last_file_list(file_path_tfidf,"csv")
#W_topic_doc(file_names_tfidf,path_topic_document,path_data_base)

# %%
def gpu_full_process(file_names_tfidf):
    
   
    #with tf.device(gpu_name):
    #print(gpu_name)
    print("************Started Session GPU *************")
    #print("sublist",file_names_tfidf,"gpu_name",gpu_name)
    W_topic_doc(file_names_tfidf,path_topic_document,path_data_base)

# %%
#gpu_full_process()

# %%
def sub_list_file(file_list_task,all_gpus):
    import math
    sub_len=math.ceil(len(file_list_task)/all_gpus)
    global_list_len=math.ceil(len(file_list_task)/sub_len)
    
    global_list=[]
    index=0
    for x in range(global_list_len):
        sublist=[]
        for i in range(sub_len):
            if index < len(file_list_task):
                sublist.append(file_list_task[index])
                index +=1
                
        global_list.append(sublist)

    return global_list

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

# %%
config = tf.ConfigProto(device_count={"GPU": 2,"CPU":1},
                        allow_soft_placement=True,
                        inter_op_parallelism_threads=16,
                        intra_op_parallelism_threads=16,
                        use_per_session_threads=True,
                        log_device_placement=True)
config.gpu_options.allow_growth = True

# %%
def distrupited_task_gpu(no_task,total_no_gpu):
    
    return no_task%total_no_gpu

# %%
#start_gpu_memory=gpu_memory_map("gpu_befor_session_memory.txt","gpu_befor_session_out.txt")
with tf.Session(config=config) as sess:
    print("************Started Session CPU *************")
    sess.run(tf.global_variables_initializer())
    #start_gpu_memory=gpu_memory_map("gpu_after_start_session_memory.txt","gpu_after_start_session_out.txt")
    #print("gpu_memory_map_after_session",start_gpu_memory) 
    
    with tf.device('/cpu'):
        
        #file_names_tfidf=read_last_file_list(file_path_tfidf,"csv")
        #print("file_list_task",file_names_tfidf)
        #sub_file_list_task=sub_list_file(file_names_tfidf,int(all_gpus))[int(gpuN)]
        #print("sub_file_list_task",sub_file_list_task)
        gpu_no=distrupited_task_gpu(int(task_no),int(all_gpus))
        gpu_name='/gpu:'+str(gpu_no)
        
        with tf.device(gpu_name):
            filename=file_path_tfidf+"split"+task_no+".csv" #"cs"+task_no+".txt" 
            gpu_full_process(filename)    

        #with tf.device(gpu_name):
            #start = timeit.default_timer()
        #gpu_full_process(sub_file_list_task)
            #Your statements here
            #print(addd("1","2"))
            #stop = timeit.default_timer()
            #print('Total Time:',stop)
# Out:
# ************Started Session CPU *************
# ************Started Session GPU *************
# d
# /home/fsg/Desktop/csv/semantics/permutation/1900s.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/abbreviation.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/abdominal.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/abidjan.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/abkhaz.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/absence.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/absolute.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/academician.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/accusation.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/accused.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/acid.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/acting.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/active.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/actor.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/acts_of_the_apostles.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ad.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/adam.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/adams.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/addition.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/address.n.07.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/adenosine_deaminase.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/administration.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/admiral.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/adolescent.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/adoption.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/adult.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/adulthood.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/advantage.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/adventure.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/aeneid.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/affect.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/africa.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/african.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/aftermath.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/agent.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/agitation.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ahura.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/aid.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/aide.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/aircraft.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/airport.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/alarm.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/alarmism.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/alaska.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/albert.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/album.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/alcohol.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/alexander.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/algonquian.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ali.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/alliance.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ally.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/altar.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/amaterasu.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ambush.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/american.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/amylase.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/analogue.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/anarchist.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ancestor.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ancient.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/anderson.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/android.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/anglesey.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/angst.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/animal.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/anne.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/anniversary.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/annual.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ant.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/antarctica.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/anti.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/antibody.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/anticipation.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/antioch.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/antony.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/apollo.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/apostle.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/appearance.n.06.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/appendix.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/appointment.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/april.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/apse.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/arabian.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/arabian_peninsula.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/arabic.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/aragon.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/arch.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/archery.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/archipelago.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/arctic.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/argentine.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/aristotle.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/arkansas.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/armenian.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/arming.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/army.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/army_for_the_liberation_of_rwanda.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/arrival.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/arrow.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/art.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/article.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/articulation.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/artist.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/artwork.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/aryan.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/asia.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/association.n.08.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/astrologer.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/astronomer.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/astronomy.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/athenaeum.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/atlantic.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/atom.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/attack.n.08.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/attempt.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/attention.n.06.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/attraction.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/auckland.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/august.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/australia.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/australian.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/austria.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/authoritarian.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/automaton.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/avail.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/average.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/avesta.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ax.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/b-complex_vitamin.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/babylon.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/bahrain.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/bailey.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ballad.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/banana.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/bangkok.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/barcelona.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/bari.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/barley.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/barrack.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/barrage.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/barter.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/basilica.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/bastard.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/battery.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/battle.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/battleship.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/bay.n.07.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/bazaar.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/beer.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/beggary.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/begin.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/beginning.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/beijing.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/benchley.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/benedick.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/benefit.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/bent.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/bering.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/berlin.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/berliner.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/best.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/better.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/bible.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/bicycle-built-for-two.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/billboard.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/billiards.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/billion.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/binding.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/biota.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/birmingham.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/birth.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/bismarck.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/bite.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/blend.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/bloc.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/bluing.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/boiling.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/bombardment.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/bonus.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/boom.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/born.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/boron.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/borrelia.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/boulder.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/boundary.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/brand.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/brewing.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/brief.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/brisbane.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/british.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/britisher.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/broadcast.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/broadcasting.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/brook.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/brown_university.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/brunei.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/brunswick.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/brutality.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/brutus.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/buddha.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/buddhism.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/buddhist.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/buddy.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/budget.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/building.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/busbar.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/business.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/business_district.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/byron.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cab.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cabinet.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cacao.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cadaver.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/calculation.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/calendar.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/california.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/camber.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/campaigner.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/campaigning.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/campsite.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/canada.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/canary_yellow.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/capacity.n.06.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cape.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/capetian.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/capitalism.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/capitalist.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/capitol.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/capture.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/car.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/carbohydrate.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/carbon_paper.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cardiff.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cardinal_number.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/care.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/career.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/career.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cargo.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/carry.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cartilage.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cash.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/castile.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/castro.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/casualty.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/catastrophe.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cathedral.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/catholic.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/catholicism.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/catholicos.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/causality.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/causing.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cayenne.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cease.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/celebes.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cellular_telephone.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/celsius.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/census.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/central.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/centre.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/centrist.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/century.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ceremony.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/chaeronea.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/championship.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/change_of_location.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/charles.n.09.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/chemical.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/chemistry.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/chest_of_drawers.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/child.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/childhood.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/chimpanzee.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/china.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/chinese.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/chip.n.08.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/chloroplast.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/chomsky.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/chosen.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/christian.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/christmas.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/christopher.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/church_service.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cigar.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cigarette.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cinderella.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/citizen.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/city.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/civilian.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/claim.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/class.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/classic.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/classical_music.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/classification.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/classified_ad.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/clemens.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/climate.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/climb.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/climber.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/clique.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/closer.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/coach.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/coaching.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/coconut.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/code.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cognition.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/coin.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/collage.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/collection.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/collective.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/collectivism.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/collectivist.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/college.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/colonel.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/colonial.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/colony.n.06.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/color.n.08.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/colorado.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/columbia_university.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/columbus.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/column.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/column.n.08.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/columnist.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/combatant.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/combustion.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/commanding_officer.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/commercial.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/commitment.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/commoner.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/commune.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/commute.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/compact_disk.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/comparative.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/comparison.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/compassion.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/complaisance.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/complex.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/component.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/computer.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/concept.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/concern.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/concert.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/conclusion.n.08.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/condition.n.08.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/conditions.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/conducting.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/confrontation.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/confusion.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/congressman.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/connection.n.07.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/consciousness.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/consent.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/conservatism.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/conservative.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/consistency.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/constant.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/constituency.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/consulate.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/consultation.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/contemplation.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/contemporary.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/contempt.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/context.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/contraction.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/control_condition.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/controversy.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/conventionality.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/conversion.n.07.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/convert.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/convict.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/conviction.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/convulsion.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/coordinate.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/coordination.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/copenhagen.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/copernicus.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/copper.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/copra.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/coral.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/corinth.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/corn_whiskey.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/costa.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/coulomb.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/council.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/count.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/countryman.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/coup_d'etat.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/couple.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/course.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/coverage.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/covering.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/crackdown.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/crash.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/crash.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/creature.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/credit_card.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/crew.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/criminal.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/criollo.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/crisis.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/crop.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cross.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cruise.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cruiser.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/crush.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/crystal.n.06.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cuba.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cull.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cumberland.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cumbria.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cup.n.08.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/curiosity.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/current.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/curvature.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/custom.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cyclone.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cylinder.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cystic_fibrosis.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/cytoplasm.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dam.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/damage.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/damon.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dancing.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/darjeeling.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/darkness.n.06.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/das_kapital.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/database.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/date.n.08.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dating.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/daughter.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dead.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/deadline.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/debate.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/debutante.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/decade.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/december.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/decision.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/decoration.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dedication.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/defeated.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/defensive_structure.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/degree.n.07.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dehydration.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/deity.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/delaware.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/delicacy.n.06.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/demeanor.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/democracy.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/democrat.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/demographic.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/demonstrator.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/demosthenes.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/denmark.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/density.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/deoxyribonucleic_acid.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/department.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/departure.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dependence.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/deputation.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/deputy.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/deriving.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/descendants.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/desert.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/deserts.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/design.n.06.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/desk.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/despair.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/destroyer.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/detachment.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/detriment.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/detroit.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/development.n.08.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/deviation.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/device.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/diagnosis.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/diagonal.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/diana.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/diaspora.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dickinson.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/die.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dietary.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/diethylstilbestrol.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/difficulty.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/diffraction.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/digest.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/digestion.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/digestive.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dioxide.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/disaccharide.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/disappearance.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/disarming.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/discharge.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/discharge.n.09.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/discipline.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/disco.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/discomfort.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/discovery.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/discovery.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/discrepancy.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/discriminative_stimulus.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/discussion.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/disease.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dismantling.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/disobedience.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/disorderliness.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dispatch.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/display.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dispute.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/disrepair.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dissolution.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/distance.n.06.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/distinction.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/distribution.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/district.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/district_attorney.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/divan.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dividend.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/doctor_of_the_church.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/documentary.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dollar.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dome.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/domestic.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dominant_allele.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dominican.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/doomed.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/doorway.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/doppler.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/doubling.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/downhill.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dowry.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/drafting.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dravidian.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/drawing.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/drew.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dreyfus.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/drift.n.07.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/driver.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/driving.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/drollery.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/drug.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/duck.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/duct.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/due.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/duration.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/duty.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dynasty.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/dysprosium.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/earner.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/east.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/eating.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ecology.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/economist.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/economy.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ecuador.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ecuadorian.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/edison.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/editing.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/edo.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/education.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/edward.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/effect.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/effect.n.06.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/effects.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/efficiency.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/efflorescence.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/egyptian.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/egyptian_empire.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/eight-spot.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/eight.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/eighteen.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/eighteenth.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/eighth.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/eighties.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/eisenhower.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/election.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/electorate.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/electric.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/electric_potential.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/element.n.07.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/elevation.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/embassy.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/emergence.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/emilia.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/emperor_butterfly.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/empire.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/employee.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/employment.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/enchantress.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/end.n.06.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/end.n.13.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ending.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/engagement.n.07.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/engineering.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/england.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/english.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/enough.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/entablature.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/enterprise.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/entertainment.n.01.csv
# dd
# d
# /home/fsg/Desktop/csv/semantics/permutation/enzyme.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/epic_poem.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/epistle.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/equilibrium.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/equipment.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/equivalent.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/era.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/eratosthenes.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/escarpment.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/estate_of_the_realm.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/estimate.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ethic.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ethnic.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ethology.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/etude.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/eugene.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/eukaryote.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/eureka.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/europe.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/european.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/european_union.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/evans.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/event.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/evidence.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/evolution.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/exception.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/exchange.n.10.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/exclusive.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/exhaustion.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/exhibition.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/exile.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/exile.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/existentialist.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/expansion.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/expense.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/experience.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/experiment.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/explanation.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/exploitation.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/exploration.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/explosive.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/export.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/express.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/extent.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/external.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/extinction.n.06.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/extrusion.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fabric.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fact.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/factory.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/failure.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fair.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fairness.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fairy.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fame.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fancier.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fantasy.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/farm.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fascism.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fast.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fastball.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fatherland.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fauna.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fear.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/feat.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/feature.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/feature_of_speech.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/february.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/federal.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/federation.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fee.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/feed.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/felt.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/female.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/feminism.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/feminist.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ferdinand.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/festival.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fever.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fibrosis.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fiction.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/field.n.10.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fifth.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fifties.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fight.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fight.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fighter.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/filing.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/film.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/film_director.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/final_examination.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/financing.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/finding.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/finish.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fire.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fire.n.08.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/firearm.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/firm.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/first_gear.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/first_step.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fischer.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fishing.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/five-spot.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/five.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fix.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/flat.n.06.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/flatulence.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fleet.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/flight.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/flight.n.09.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/floor.n.10.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/floorboard.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/florence.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/flourish.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fluid.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fluorine.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/focus.n.07.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/foe.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/foil.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/following.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fonda.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/food.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/foot.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/football.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/football_team.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/footing.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/foray.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/forest.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/formation.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/former.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/forth.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/forum.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/forward.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/found.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/foundation_garment.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/founder.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/four-spot.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fourteen.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/france.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/frankincense.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/frederick.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/frederick_i.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/free.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/freedom.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/french.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/front-runner.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/full_moon.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fundamental_law.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/fur.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/future.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/gabon.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/galactose.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/galatian.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/galaxy.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/galileo.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/garden.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/gene.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/general.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/genetics.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/genius.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/genoa.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/genome.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/genotype.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/georgia.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/georgian.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/german.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/germany.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/girlfriend.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/give.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/given.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/gluten.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/go.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/goal.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/goalkeeper.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/goddess.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/going.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/gold.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/goldfield.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/golf.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/golf_club.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/good.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/good_morning.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/gorbachev.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/governed.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/government.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/government.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/graduate.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/granada.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/grand_piano.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/grandson.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/gravy_boat.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/great.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/greek.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/grenade.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/grimm.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/grind.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/groove.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/grotius.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ground.n.09.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/group.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/growth.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/grudge.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/guanine.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/guardianship.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/guess.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/guevara.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/guiana.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/guilt.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/guise.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/gulf.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/gulp.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/gunfire.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/gunman.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/gunpowder.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/gypsy.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/gyration.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/haitian.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hakham.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hampshire.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hampton.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hand_brake.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/handle.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hanoi.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/harkat-ul-mujahidin.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/havana.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hawaii.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hazard.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/heading.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/headquarters.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/health.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/heart.n.10.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/heating_system.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/heavy.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hectometer.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/henry.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/herat.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/herbert.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/heredity.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/heresy.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hertfordshire.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hertz.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hide.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hill.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hindenburg.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hindu.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hint.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hip.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hired_hand.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/historian.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/history.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/history.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hit.n.07.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ho_chi_minh_city.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hobbit.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hold.n.07.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hole.n.06.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/holiday.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/holmium.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/holocene.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/holy_place.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/home_plate.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/homo.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/homosexual.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/honor.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hook.n.06.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hop.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hope.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/horizontal.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/horseman.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hospital.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hostility.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hotel.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hour.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hour.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hours.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/housing.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hovel.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hudson.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hugo.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/human_body.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hundred.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hunt.n.08.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hurricane.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/husk.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hydrogen.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/hypertext_markup_language.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/iberian.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/ice-cream_soda.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/iceland.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/identification.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/identity.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/imagination.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/immigrant.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/immigration.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/immorality.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/immunoglobulin.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/impact.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/imperial.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/implementation.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/implosion_therapy.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/importance.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/impossible.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/imposter.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/impression.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/inch.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/incidental_expense.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/increase.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/independence.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/index.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/india.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/indian.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/indomitability.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/indulgence.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/industrial_workers_of_the_world.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/industry.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/inequality.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/infection.n.07.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/influence.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/information.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/information_science.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/infusion.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/inhabitant.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/inheritance.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/initial.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/initial_public_offering.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/initiation.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/inkling.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/inquiry.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/inquisition.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/inside.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/inspiration.n.05.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/institute.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/instruction.n.04.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/intellectual.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/intelligence.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/intention.n.03.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/intercept.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/interim.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/interlingua.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/international.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/internationale.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/interpretation.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/intervention.n.02.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/interview.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/intestine.n.01.csv
# d
# /home/fsg/Desktop/csv/semantics/permutation/intravenous_feeding.n.01.csv
